# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# amphetamines confusion matrix
title = 'Amphetamines confusion matrix: Random Forest'
cm = np.array([[241, 66], [27, 136]])
classes = ['Non-User', 'User']
cmap = plt.cm.Blues

fig, ax = plt.subplots()
im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
ax.figure.colorbar(im, ax=ax)
ax.set(xticks=np.arange(cm.shape[1]),
      yticks=np.arange(cm.shape[0]),
      xticklabels=classes,
      yticklabels=classes,
      title=title,
      ylabel='True label',
      xlabel='Predicted label')
fmt = 'd'
thresh = 241/2
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(j, i, format(cm[i, j], fmt),
               ha="center", va='center',
               color='white' if cm[i, j] > thresh else 'black')
fig.tight_layout()
plt.plot();

# %%
# meth confusion matrix
title = 'Meth Confusion Matrix: Decsion Tree'
cm = np.array([[300, 72], [20, 78]])
classes = ['Non-User', 'User']
cmap = plt.cm.Blues

fig, ax = plt.subplots()
im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
ax.figure.colorbar(im, ax=ax)
ax.set(xticks=np.arange(cm.shape[1]),
      yticks=np.arange(cm.shape[0]),
      xticklabels=classes,
      yticklabels=classes,
      title=title,
      ylabel='True label',
      xlabel='Predicted label')
fmt = 'd'
thresh = 241/2
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(j, i, format(cm[i, j], fmt),
               ha="center", va='center',
               color='white' if cm[i, j] > thresh else 'black')
fig.tight_layout()
plt.plot();

# %%
# heroin confusion matrix
title = 'Heroin Confusion Matrix: AdaBoost'
cm = np.array([[389, 27], [19, 35]])
classes = ['Non-User', 'User']
cmap = plt.cm.Blues

fig, ax = plt.subplots()
im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
ax.figure.colorbar(im, ax=ax)
ax.set(xticks=np.arange(cm.shape[1]),
      yticks=np.arange(cm.shape[0]),
      xticklabels=classes,
      yticklabels=classes,
      title=title,
      ylabel='True label',
      xlabel='Predicted label')
fmt = 'd'
thresh = 241/2
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(j, i, format(cm[i, j], fmt),
               ha="center", va='center',
               color='white' if cm[i, j] > thresh else 'black')
fig.tight_layout()
plt.plot();
